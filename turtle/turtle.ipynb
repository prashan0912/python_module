# %%
from turtle import Turtle , Screen
t = Turtle();
screen = Screen();
t.shape("turtle")
screen.exitonclick()

# %%
from turtle import Turtle , Screen
t = Turtle();
screen = Screen();
t.shape("turtle")
screen.exitonclick()

# %%
from turtle import Turtle , Screen
t = Turtle();
screen = Screen();
t.shape("turtle")
t.forward(100)
screen.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from turtle import Turtle , Screen
# ----> 2 t = Turtle();
#       3 screen = Screen();
#       4 t.shape("turtle")
#       5 t.color("green")
#
# File c:\Users\Prashant Sahu.DESKTOP-IQSLMAE\AppData\Local\Programs\Python\Python314\Lib\turtle.py:3960, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3958 if Turtle._screen is None:
#    3959     Turtle._screen = Screen()
# -> 3960 RawTurtle.__init__(self, Turtle._screen,
#    3961                    shape=shape,
#    3962                    undobuffersize=undobuffersize,
#    3963                    visible=visible)
#
# File c:\Users\Prashant Sahu.DESKTOP-IQSLMAE\AppData\Local\Programs\Python\Python314\Lib\turtle.py:2641, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2639 self._undobuffersize = undobuffersize
# ...
