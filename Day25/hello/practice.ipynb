# %%
import pandas as pd

data = pd.read_csv("new_data.csv")
print(data)

print(data["scores"])

new_score = [n+5 for n in data.scores]
print(new_score)

print(data.loc[data["scores"].idxmax(), "students"])
# Out:
#    Sno. students  scores
# 0     0      Amy      76
# 1     1    James      56
# 2     2   Angela      65
# 0    76
# 1    56
# 2    65
# Name: scores, dtype: int64
# [81, 61, 70]
# Amy
