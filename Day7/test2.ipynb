# %%
display = "apple"
guess = "a"

for index,char in enumerate(display):
    if char == guess:
        # display[index] = guess
        found = True
        print(char,index)
        
for i in display:
    print(i)
# Out:
# a 0
# a
# p
# p
# l
# e
