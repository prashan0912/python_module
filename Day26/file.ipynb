# %%
numbers = [1,2,3]
new_number = [n+1 for n in numbers]
print(new_number)
# Out:
# [2, 3, 4]

# %%
letter = "hello"
letter_list = [l for l in letter]
print(letter_list)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
list_square = [num*2 for num in range(1,11)]
print(list_square)
# Out:
# [2, 4, 6, 8, 10]

# %%
name_list=["Prashant","Sahu","Rohit","Sharma"]

new_list=[n for n in name_list if len(n)>5]
new_list=[n.upper() for n in name_list if len(n)>5]

print(new_list)
# Out:
# ['PRASHANT', 'SHARMA']

# %%
name = ["Alex","Beth","Caroline","Dave","Eleanor","Freddie"]
import random
student_score = {student:random.randint(1,100) for student in name}
print(student_score)
# Out:
# {'Alex': 38, 'Beth': 78, 'Caroline': 45, 'Dave': 6, 'Eleanor': 17, 'Freddie': 94}

# %%
passed_students = {student:score for (student,score) in student_score.items() if score>=60}
print(passed_students)
# Out:
# {'Beth': 78, 'Freddie': 94}

# %%
weather_c = {"Monday": 12, "Tuesday": 14, "Wednesday": 15, "Thursday": 14, "Friday": 21, "Saturday": 22, "Sunday": 24}

weather_f = {day:(temp * 9/5) + 32 for (day, temp) in weather_c.items()}

print(weather_f)
# Out:
# {'Monday': 53.6, 'Tuesday': 57.2, 'Wednesday': 59.0, 'Thursday': 57.2, 'Friday': 69.8, 'Saturday': 71.6, 'Sunday': 75.2}

# %%
sentence = "What is the Airspeed Velocity of an Unladen Swallow?"
result = {word : len(word) for word in sentence.split()}

# %%
#For Loop
numbers = [1, 2, 3]
new_list = []
for n in numbers:
    add_1 = n + 1
    new_list.append(add_1)

#List Comprehension
new_list = [n + 1 for n in numbers]

#String as List
name = "Angela"
letters_list = [letter for letter in name]

#Range as List
range_list = [n * 2 for n in range(1, 5)]

#Conditional List Comprenhension
names = ["Alex", "Beth", "Caroline", "Dave", "Elanor", "Freddie"]
short_names = [name for name in names if len(name) < 5]

upper_case_names = [name.upper() for name in names if len(name) > 4]

#Dictionary Comprehension
import random
student_grades = {name: random.randint(1, 100) for name in names}
print(student_grades)

passed_students = {
    student: grade
    for (student, grade) in student_grades.items() if grade >= 60
}
print(passed_students)
# Out:
# {'Alex': 45, 'Beth': 4, 'Caroline': 20, 'Dave': 51, 'Elanor': 58, 'Freddie': 65}
# {'Freddie': 65}

# %%
student_dict={
    "student":["Angela","James","Lily"],
    "score":[56, 76, 98]
}
for (key, value) in student_dict.items():
    print(value)
# Out:
# ['Angela', 'James', 'Lily']
# [56, 76, 98]

# %%
student_dict={
    "student":["Angela","James","Lily"],
    "score":[56, 76, 98]
}

passed_students = {
    student: grade
    for (student, grade) in student_grades.items() if grade >= 60
}
print(passed_students)


import pandas
student_data_frame = pandas.DataFrame(student_dict)
print(student_data_frame)

for(index, row) in student_data_frame.iterrows():
    print(index)
    print(row.student)
    print(row.score)
# Out:
# {'Freddie': 65}
#   student  score
# 0  Angela     56
# 1   James     76
# 2    Lily     98
# 0
# Angela
# 56
# 1
# James
# 76
# 2
# Lily
# 98

# %%
for(index, row) in student_data_frame.iterrows():
    if row.student == "Angela":
        print(row.score)
# Out:
# 56
