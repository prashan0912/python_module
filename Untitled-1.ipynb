# %% [markdown]
# First Program

# %%
arr = ["a","b","c","d","e","f"];
print(arr)
print(arr[0:3])
print(arr[-5:-1])
print(arr[0:4])
print(arr[-3:-1])
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['a', 'b', 'c']
# ['b', 'c', 'd', 'e']
# ['a', 'b', 'c', 'd']
# ['d', 'e']

# %%
print("hello world")

#both are okay infact this is better way to write code 
print("hello world"); 

# how to print in next line
print(" hello world 1 \n hello world 2 \n hello world 3 ");

#cancatination
print("Prashant"+"Sahu")

print("Apple"+" "+"Banana")

print ("PineApple")


a = 10;
print(a);
# Out:
# hello world
# hello world
#  hello world 1
#  hello world 2
#  hello world 3
# PrashantSahu
# Apple Banana
# PineApple
# 10

# %%
# input("Write your prompt");

# print("hello" , input("what is your name"));


a = input("write your name here");
print("hello"+a)

# %%
# Out:
# Original DataFrame:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
#
# Summary statistics:
#         Age   Salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0
#
# DataFrame with Bonus column:
#       Name  Age  Salary   Bonus
# 0    Alice   25   50000  5000.0
# 1      Bob   30   60000  6000.0
# 2  Charlie   35   70000  7000.0
#
# Filtered DataFrame (Age > 28):
#       Name  Age  Salary   Bonus
# 1      Bob   30   60000  6000.0
# 2  Charlie   35   70000  7000.0
