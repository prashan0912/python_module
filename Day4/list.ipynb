# %%
arr = []

arr.append(12)
arr.append(30)

print(arr)


arr.insert(1,40)
print(arr)

for i in range(0,5):
    arr.append(i)
    print(arr)
    
print(max(arr))
# Out:
# [12, 30]
# [12, 40, 30]
# [12, 40, 30, 0]
# [12, 40, 30, 0, 1]
# [12, 40, 30, 0, 1, 2]
# [12, 40, 30, 0, 1, 2, 3]
# [12, 40, 30, 0, 1, 2, 3, 4]
# 40

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
