# %%
#subscripting 
print("HelloWorld"[0])
print("HelloWorld"[-1])
print("HelloWorld"[4])
print("HelloWorld"[-3])
# Out:
# H
# d
# o
# r

# %%
# string
print("123"+"345"); #concatination

#integer = whole Number
print(123+123);
print(type("123"+"123"))

#Largest Integer
print(123_234_456);
print(type(123_123_123))

#Float
print(123.123)
print(type(123.123))

#Boolean
print(True);
print(type(True));
print(False);
# Out:
# 123345
# 246
# <class 'str'>
# 123234456
# <class 'int'>
# 123.123
# <class 'float'>
# True
# <class 'bool'>
# False

# %%
len() # return the number of item in any object , the argument maybe sequence or a collection such as string ,byte , couple , list ,or range

# %%
print(int("123")+int("123"))
print(int("abc")+int(123)) #error of invalid literal for int() with base 10: 'abc'
# Out:
# 246
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 print(int("123")+int("123"))
# ----> 2 print(int("abc")+int(123))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
print(int())
print(float())
print(bool())
print(str())
# Out:
# 0
# 0.0
# False

# %%
print(1+1)
print(2-1)
print(3*2)
print(5/3)
print(type(5/3))
print(25**2)
print(5//3)
print(type(5//3))#provide floor

import math as Math
print(Math.ceil(22/7))
print(Math.floor(22/7))
print(round(22/7))
# Out:
# 2
# 1
# 6
# 1.6666666666666667
# <class 'float'>
# 625
# 1
# <class 'int'>
# 4
# 3
# 3

# %%
#Parentheses, Exponents, Multiplication and Division, Addition and Subtraction, Left to Right
print(3*(3+3)/3-3)
print(3*3+3/3-3)

print(3*4/3)
print(3/4*3)
# Out:
# 3.0
# 7.0
# 4.0
# 2.25

# %%
score = 12
height = 190.43
is_winning = True 

print(f"score of match ={score} ,height is ={height}, is winning ={is_winning}")
print("score of match =", score, ",height is =", height, ", is winning =", is_winning)
print("score of match =" + str(score))
# Out:
# score of match =12 ,height is =190.43, is winning =True
# score of match = 12 ,height is = 190.43 , is winning = True
# score of match =12
