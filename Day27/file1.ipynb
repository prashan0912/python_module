# %%
import tkinter
window=tkinter.Tk()
window.title("File Dialog")
window.minsize(width=400, height=400)

window.mainloop()

my_label = tkinter.Label(text="This is a label", font=("Arial", 24, "bold"))
my_label.pack()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 6
#       2 window=tkinter.Tk()
#       3 window.title("File Dialog")
#       4 window.minsize(width=400, height=400)
#       5
# ----> 6 window.mainloop()
#       7
#       8 my_label = tkinter.Label(text="This is a label", font=("Arial", 24, "bold"))
#       9 my_label.pack()
#
# File c:\Users\Prashant Sahu.DESKTOP-IQSLMAE\AppData\Local\Programs\Python\Python314\Lib\tkinter\__init__.py:1613, in Misc.mainloop(self, n)
#    1611 def mainloop(self, n=0):
#    1612     """Call the mainloop of Tk."""
# -> 1613     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import tkinter as tk

# Create main window
root = tk.Tk()
root.title("My First App")
root.geometry("400x300")

# Run the application
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       5 root.title("My First App")
#       6 root.geometry("400x300")
#       7
#       8 # Run the application
# ----> 9 root.mainloop()
#
# File c:\Users\Prashant Sahu.DESKTOP-IQSLMAE\AppData\Local\Programs\Python\Python314\Lib\tkinter\__init__.py:1613, in Misc.mainloop(self, n)
#    1611 def mainloop(self, n=0):
#    1612     """Call the mainloop of Tk."""
# -> 1613     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import tkinter as tk

root = tk.Tk()
root.title("Label Example")
root.geometry("400x300")
label = tk.Label(root, text="Hello, Tkinter!", font=("Arial", 16))
label.pack()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 9
#       5 root.geometry("400x300")
#       6 label = tk.Label(root, text="Hello, Tkinter!", font=("Arial", 16))
#       7 label.pack()
#       8
# ----> 9 root.mainloop()
#
# File c:\Users\Prashant Sahu.DESKTOP-IQSLMAE\AppData\Local\Programs\Python\Python314\Lib\tkinter\__init__.py:1613, in Misc.mainloop(self, n)
#    1611 def mainloop(self, n=0):
#    1612     """Call the mainloop of Tk."""
# -> 1613     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import tkinter as tk

def on_closing():
    print("Window is closing...")
    root.destroy()   # closes window and stops program

root = tk.Tk()
root.title("Close Example")

root.protocol("WM_DELETE_WINDOW", on_closing)

root.mainloop()
# Out:
# Window is closing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 12
#       8 root.title("Close Example")
#       9
#      10 root.protocol("WM_DELETE_WINDOW", on_closing)
#      11
# ---> 12 root.mainloop()
#
# File c:\Users\Prashant Sahu.DESKTOP-IQSLMAE\AppData\Local\Programs\Python\Python314\Lib\tkinter\__init__.py:1613, in Misc.mainloop(self, n)
#    1611 def mainloop(self, n=0):
#    1612     """Call the mainloop of Tk."""
# -> 1613     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import pandas as pd

data = pd.DataFrame({
    "student": ["Angela", "James", "Lily"],
    "score": [56, 76, 98]
})

list = [n for n in data.score if n == data.score.max()]
print(list)

print([n for n in data.student ])

print(n for n in data)
# Out:
# [98]
# ['Angela', 'James', 'Lily']
